# %%
print("Hello, AI World!")
# Out:
# Hello, AI World!

# %% [markdown]
# Explain what Artificial Intelligence means to you.
#
# To me, it means something human-made that can make decisions. Like a calculator is a form of AI as it makes a decision of what to output after an equation is inputted. Though I'm not sure if I would classify a coin toss as an AI, as it doesn't make decisions, just following the rules of classical mechanics. Then again, the same thing could be said for a calculator.

# %% [markdown]
# Why do people fear the rise of AI?
#
# I think people fear AI partially becuase of movies like Terminator, but I think the main reason is that humans fear being not special or needed. If your job can be done by AI for cheap, then you are no longer special and no longer needed.

# %% [markdown]
# Where does AI currently outperform humans, and where do humans remain stronger?
#
#
# AI, especially LLMs like GPT5.2 thinking and Gemini 3 pro, currently outperforms in human being jack of all trades, and a master in finding and utalizing information. What I haven't observed in AI that I have in humans is that AIs do not make anything new without human guidance, so I'd say innovation may be human's strength. Or perhaps, as of now, it's humans' autonomy and capability of interacting with the real world. Something that suprised me is when I heard of an AI coming up with Newton's 3 Laws of physics by just interacting with a simulation.

# %% [markdown]
# Finance:
#
# One benefit AI could bring
#
# I think AI could help automate a lot of things in finance, especially in accounting. From my best understanding, a lot of high level accouting is finding the best way save money while following all the rules, like when filing taxes. AI should be good at following those rules and coming up with ways to minimize loses. In other parts of finance, I'm sure it can help brainstorm with its great vast amounts of knowledge.
#
#
# One challenge or ethical concern it raises
#
# A challenge that I could see happening is the question of "How can I keep a computer accountable" when much of an industry starts to rely on it. Especially in finance, if a corperation with decides to trust some AUM to an AI, and it makes a mistake for some reason, it would be very difficult to find who to blame. Another concern is that of over dependency on AI, even if it's not perfect. Just submitting whatever an LLM outputs is likely going to lead to unfortunate circumstances.
